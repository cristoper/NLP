# %%
import pandas as pd
from google import search

# %% [markdown]
# # Overview: Purpose is to develop methodology to create a network of Item banks, Platforms, and School Districts

# %% [markdown]
# ## Creating Spreadsheets

# %% [markdown]
# Step 1: Item Banks and Partners.  Go to all Item banks in the table presented in the NCME presentation, and find the assoicated platform partners. From here, go to each platform partner website and find any platform parters that look like they could possibly also use items from the item bank. Therefore, the manual search will look something like this:

# %% [markdown]
# Step 2: Large School Districts. Go to the wikipedia page, and find the largest school districts in the country (right now, there are only 50).

# %%
item_partners = pd.read_csv("/Users/amyburkhardt/Dropbox/ItemBankInvestigation/ItemBank_Network.csv")
item_partners['ItemBankPartners'] = '"' + item_partners['ItemBankPartners'] + '"'
item_partners['PlatformPartners'] = '"' + item_partners['PlatformPartners'] + '"'
item_partners.head(5)
# Out:
#          ItemBank                  ItemBankPartners  \
# 0  KeyDataSystems  "Five-star technology solutions"
# 1  KeyDataSystems  "Five-star technology solutions"
# 2  KeyDataSystems  "Five-star technology solutions"
# 3  KeyDataSystems  "Five-star technology solutions"
# 4  KeyDataSystems  "Five-star technology solutions"
#
#                  PlatformPartners
# 0               "close education"
# 1         "destination knowledge"
# 2              "edgED consulting"
# 3  "equitable education solution"
# 4                "KeyDataSystems"

# %%
schools = pd.read_csv("/Users/amyburkhardt/Dropbox/ItemBankInvestigation/schoolDistricts.csv")
schools['School District'] = '"' + schools['School District'] + '"'
schools.head()
# Out:
#                            School District
# 0  "New York City Department of Education"
# 1    "Los Angeles Unified School District"
# 2    "Puerto Rico Department of Education"
# 3                 "Chicago Public Schools"
# 4       "Miami-Dade County Public Schools"

# %% [markdown]
# ## Create Search Terms

# %% [markdown]
# For every ItemBankPartners and PlatformsPartners, combine with the school district to create search_terms for every record. For example, the search_terms for the first observation will be the following: <p>
# "'Five-star technology solutions'" AND "'New York City Department of Education'" <p>
# "'close education'" AND "'New York City Department of Education'" <p>
# "'Five-star technology solutions'" AND "'Los Angeles Unified School District'" <p>
# "'close education'" AND "'Los Angeles Unified School District'" <p>
# . <p>
# . <p>
# . <p>
# etc.

# %%
item_bank_partners = item_partners[['ItemBankPartners']]
item_bank_partners = item_bank_partners.rename(columns = {'ItemBankPartners': 'vendor'})
platform_partners = item_partners[['PlatformPartners']]
platform_partners = platform_partners.rename(columns = {'PlatformPartners': 'vendor'})
item_bank_partners = item_bank_partners.drop_duplicates()
platform_partners  = platform_partners.drop_duplicates()
eligible_vendors = pd.concat([item_bank_partners, platform_partners])

# %%
search_terms = []
for school in schools['School District']:
    for ven in eligible_vendors['vendor']: 
        term = "{} AND {} AND assessment".format(ven, school)
        search_terms.append(term)
search_terms
# Out:
# ['"Five-star technology solutions" AND "New York City Department of Education" AND assessment',
#  '"onHands Schools" AND "New York City Department of Education" AND assessment',
#  '"Edluastic" AND "New York City Department of Education" AND assessment',
#  '"PowerSchool" AND "New York City Department of Education" AND assessment',
#  '"eduphoria" AND "New York City Department of Education" AND assessment',
#  '"Otus" AND "New York City Department of Education" AND assessment',
#  '"eDoctrina" AND "New York City Department of Education" AND assessment',
#  '"Mastery Connect" AND "New York City Department of Education" AND assessment',
#  '"performance matters" AND "New York City Department of Education" AND assessment',
#  '"illuminate education" AND "New York City Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "New York City Department of Education" AND assessment',
#  '"engrade" AND "New York City Department of Education" AND assessment',
#  '"SchoolCity" AND "New York City Department of Education" AND assessment',
#  '"Naiku" AND "New York City Department of Education" AND assessment',
#  '"OARS" AND "New York City Department of Education" AND assessment',
#  '"oncourse " AND "New York City Department of Education" AND assessment',
#  '"schoolnet" AND "New York City Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "New York City Department of Education" AND assessment',
#  '"Edupoint" AND "New York City Department of Education" AND assessment',
#  '"io education" AND "New York City Department of Education" AND assessment',
#  '"close education" AND "New York City Department of Education" AND assessment',
#  '"destination knowledge" AND "New York City Department of Education" AND assessment',
#  '"edgED consulting" AND "New York City Department of Education" AND assessment',
#  '"equitable education solution" AND "New York City Department of Education" AND assessment',
#  '"KeyDataSystems" AND "New York City Department of Education" AND assessment',
#  '"IMLEA" AND "New York City Department of Education" AND assessment',
#  '"massp" AND "New York City Department of Education" AND assessment',
#  '"mindplay" AND "New York City Department of Education" AND assessment',
#  '"TheNationalForum" AND "New York City Department of Education" AND assessment',
#  '"NETWORK for quality education" AND "New York City Department of Education" AND assessment',
#  '"strategos group" AND "New York City Department of Education" AND assessment',
#  '"Texas Education Solutions " AND "New York City Department of Education" AND assessment',
#  'nan AND "New York City Department of Education" AND assessment',
#  '"Google for Education Partner" AND "New York City Department of Education" AND assessment',
#  '"Carnegie Learning, Inc. " AND "New York City Department of Education" AND assessment',
#  '"QuickKey" AND "New York City Department of Education" AND assessment',
#  '"Certica Solutions" AND "New York City Department of Education" AND assessment',
#  '"STAAR Test Maker" AND "New York City Department of Education" AND assessment',
#  '"TEKSbank " AND "New York City Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Los Angeles Unified School District" AND assessment',
#  '"onHands Schools" AND "Los Angeles Unified School District" AND assessment',
#  '"Edluastic" AND "Los Angeles Unified School District" AND assessment',
#  '"PowerSchool" AND "Los Angeles Unified School District" AND assessment',
#  '"eduphoria" AND "Los Angeles Unified School District" AND assessment',
#  '"Otus" AND "Los Angeles Unified School District" AND assessment',
#  '"eDoctrina" AND "Los Angeles Unified School District" AND assessment',
#  '"Mastery Connect" AND "Los Angeles Unified School District" AND assessment',
#  '"performance matters" AND "Los Angeles Unified School District" AND assessment',
#  '"illuminate education" AND "Los Angeles Unified School District" AND assessment',
#  '"FOCALPOINTK12" AND "Los Angeles Unified School District" AND assessment',
#  '"engrade" AND "Los Angeles Unified School District" AND assessment',
#  '"SchoolCity" AND "Los Angeles Unified School District" AND assessment',
#  '"Naiku" AND "Los Angeles Unified School District" AND assessment',
#  '"OARS" AND "Los Angeles Unified School District" AND assessment',
#  '"oncourse " AND "Los Angeles Unified School District" AND assessment',
#  '"schoolnet" AND "Los Angeles Unified School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Los Angeles Unified School District" AND assessment',
#  '"Edupoint" AND "Los Angeles Unified School District" AND assessment',
#  '"io education" AND "Los Angeles Unified School District" AND assessment',
#  '"close education" AND "Los Angeles Unified School District" AND assessment',
#  '"destination knowledge" AND "Los Angeles Unified School District" AND assessment',
#  '"edgED consulting" AND "Los Angeles Unified School District" AND assessment',
#  '"equitable education solution" AND "Los Angeles Unified School District" AND assessment',
#  '"KeyDataSystems" AND "Los Angeles Unified School District" AND assessment',
#  '"IMLEA" AND "Los Angeles Unified School District" AND assessment',
#  '"massp" AND "Los Angeles Unified School District" AND assessment',
#  '"mindplay" AND "Los Angeles Unified School District" AND assessment',
#  '"TheNationalForum" AND "Los Angeles Unified School District" AND assessment',
#  '"NETWORK for quality education" AND "Los Angeles Unified School District" AND assessment',
#  '"strategos group" AND "Los Angeles Unified School District" AND assessment',
#  '"Texas Education Solutions " AND "Los Angeles Unified School District" AND assessment',
#  'nan AND "Los Angeles Unified School District" AND assessment',
#  '"Google for Education Partner" AND "Los Angeles Unified School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Los Angeles Unified School District" AND assessment',
#  '"QuickKey" AND "Los Angeles Unified School District" AND assessment',
#  '"Certica Solutions" AND "Los Angeles Unified School District" AND assessment',
#  '"STAAR Test Maker" AND "Los Angeles Unified School District" AND assessment',
#  '"TEKSbank " AND "Los Angeles Unified School District" AND assessment',
#  '"Five-star technology solutions" AND "Puerto Rico Department of Education" AND assessment',
#  '"onHands Schools" AND "Puerto Rico Department of Education" AND assessment',
#  '"Edluastic" AND "Puerto Rico Department of Education" AND assessment',
#  '"PowerSchool" AND "Puerto Rico Department of Education" AND assessment',
#  '"eduphoria" AND "Puerto Rico Department of Education" AND assessment',
#  '"Otus" AND "Puerto Rico Department of Education" AND assessment',
#  '"eDoctrina" AND "Puerto Rico Department of Education" AND assessment',
#  '"Mastery Connect" AND "Puerto Rico Department of Education" AND assessment',
#  '"performance matters" AND "Puerto Rico Department of Education" AND assessment',
#  '"illuminate education" AND "Puerto Rico Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "Puerto Rico Department of Education" AND assessment',
#  '"engrade" AND "Puerto Rico Department of Education" AND assessment',
#  '"SchoolCity" AND "Puerto Rico Department of Education" AND assessment',
#  '"Naiku" AND "Puerto Rico Department of Education" AND assessment',
#  '"OARS" AND "Puerto Rico Department of Education" AND assessment',
#  '"oncourse " AND "Puerto Rico Department of Education" AND assessment',
#  '"schoolnet" AND "Puerto Rico Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "Puerto Rico Department of Education" AND assessment',
#  '"Edupoint" AND "Puerto Rico Department of Education" AND assessment',
#  '"io education" AND "Puerto Rico Department of Education" AND assessment',
#  '"close education" AND "Puerto Rico Department of Education" AND assessment',
#  '"destination knowledge" AND "Puerto Rico Department of Education" AND assessment',
#  '"edgED consulting" AND "Puerto Rico Department of Education" AND assessment',
#  '"equitable education solution" AND "Puerto Rico Department of Education" AND assessment',
#  '"KeyDataSystems" AND "Puerto Rico Department of Education" AND assessment',
#  '"IMLEA" AND "Puerto Rico Department of Education" AND assessment',
#  '"massp" AND "Puerto Rico Department of Education" AND assessment',
#  '"mindplay" AND "Puerto Rico Department of Education" AND assessment',
#  '"TheNationalForum" AND "Puerto Rico Department of Education" AND assessment',
#  '"NETWORK for quality education" AND "Puerto Rico Department of Education" AND assessment',
#  '"strategos group" AND "Puerto Rico Department of Education" AND assessment',
#  '"Texas Education Solutions " AND "Puerto Rico Department of Education" AND assessment',
#  'nan AND "Puerto Rico Department of Education" AND assessment',
#  '"Google for Education Partner" AND "Puerto Rico Department of Education" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Puerto Rico Department of Education" AND assessment',
#  '"QuickKey" AND "Puerto Rico Department of Education" AND assessment',
#  '"Certica Solutions" AND "Puerto Rico Department of Education" AND assessment',
#  '"STAAR Test Maker" AND "Puerto Rico Department of Education" AND assessment',
#  '"TEKSbank " AND "Puerto Rico Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Chicago Public Schools" AND assessment',
#  '"onHands Schools" AND "Chicago Public Schools" AND assessment',
#  '"Edluastic" AND "Chicago Public Schools" AND assessment',
#  '"PowerSchool" AND "Chicago Public Schools" AND assessment',
#  '"eduphoria" AND "Chicago Public Schools" AND assessment',
#  '"Otus" AND "Chicago Public Schools" AND assessment',
#  '"eDoctrina" AND "Chicago Public Schools" AND assessment',
#  '"Mastery Connect" AND "Chicago Public Schools" AND assessment',
#  '"performance matters" AND "Chicago Public Schools" AND assessment',
#  '"illuminate education" AND "Chicago Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Chicago Public Schools" AND assessment',
#  '"engrade" AND "Chicago Public Schools" AND assessment',
#  '"SchoolCity" AND "Chicago Public Schools" AND assessment',
#  '"Naiku" AND "Chicago Public Schools" AND assessment',
#  '"OARS" AND "Chicago Public Schools" AND assessment',
#  '"oncourse " AND "Chicago Public Schools" AND assessment',
#  '"schoolnet" AND "Chicago Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Chicago Public Schools" AND assessment',
#  '"Edupoint" AND "Chicago Public Schools" AND assessment',
#  '"io education" AND "Chicago Public Schools" AND assessment',
#  '"close education" AND "Chicago Public Schools" AND assessment',
#  '"destination knowledge" AND "Chicago Public Schools" AND assessment',
#  '"edgED consulting" AND "Chicago Public Schools" AND assessment',
#  '"equitable education solution" AND "Chicago Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Chicago Public Schools" AND assessment',
#  '"IMLEA" AND "Chicago Public Schools" AND assessment',
#  '"massp" AND "Chicago Public Schools" AND assessment',
#  '"mindplay" AND "Chicago Public Schools" AND assessment',
#  '"TheNationalForum" AND "Chicago Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Chicago Public Schools" AND assessment',
#  '"strategos group" AND "Chicago Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Chicago Public Schools" AND assessment',
#  'nan AND "Chicago Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Chicago Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Chicago Public Schools" AND assessment',
#  '"QuickKey" AND "Chicago Public Schools" AND assessment',
#  '"Certica Solutions" AND "Chicago Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Chicago Public Schools" AND assessment',
#  '"TEKSbank " AND "Chicago Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Miami-Dade County Public Schools" AND assessment',
#  '"onHands Schools" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Edluastic" AND "Miami-Dade County Public Schools" AND assessment',
#  '"PowerSchool" AND "Miami-Dade County Public Schools" AND assessment',
#  '"eduphoria" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Otus" AND "Miami-Dade County Public Schools" AND assessment',
#  '"eDoctrina" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Miami-Dade County Public Schools" AND assessment',
#  '"performance matters" AND "Miami-Dade County Public Schools" AND assessment',
#  '"illuminate education" AND "Miami-Dade County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Miami-Dade County Public Schools" AND assessment',
#  '"engrade" AND "Miami-Dade County Public Schools" AND assessment',
#  '"SchoolCity" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Naiku" AND "Miami-Dade County Public Schools" AND assessment',
#  '"OARS" AND "Miami-Dade County Public Schools" AND assessment',
#  '"oncourse " AND "Miami-Dade County Public Schools" AND assessment',
#  '"schoolnet" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Edupoint" AND "Miami-Dade County Public Schools" AND assessment',
#  '"io education" AND "Miami-Dade County Public Schools" AND assessment',
#  '"close education" AND "Miami-Dade County Public Schools" AND assessment',
#  '"destination knowledge" AND "Miami-Dade County Public Schools" AND assessment',
#  '"edgED consulting" AND "Miami-Dade County Public Schools" AND assessment',
#  '"equitable education solution" AND "Miami-Dade County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Miami-Dade County Public Schools" AND assessment',
#  '"IMLEA" AND "Miami-Dade County Public Schools" AND assessment',
#  '"massp" AND "Miami-Dade County Public Schools" AND assessment',
#  '"mindplay" AND "Miami-Dade County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Miami-Dade County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Miami-Dade County Public Schools" AND assessment',
#  '"strategos group" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Miami-Dade County Public Schools" AND assessment',
#  'nan AND "Miami-Dade County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Miami-Dade County Public Schools" AND assessment',
#  '"QuickKey" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Miami-Dade County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Miami-Dade County Public Schools" AND assessment',
#  '"TEKSbank " AND "Miami-Dade County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Clark County School District" AND assessment',
#  '"onHands Schools" AND "Clark County School District" AND assessment',
#  '"Edluastic" AND "Clark County School District" AND assessment',
#  '"PowerSchool" AND "Clark County School District" AND assessment',
#  '"eduphoria" AND "Clark County School District" AND assessment',
#  '"Otus" AND "Clark County School District" AND assessment',
#  '"eDoctrina" AND "Clark County School District" AND assessment',
#  '"Mastery Connect" AND "Clark County School District" AND assessment',
#  '"performance matters" AND "Clark County School District" AND assessment',
#  '"illuminate education" AND "Clark County School District" AND assessment',
#  '"FOCALPOINTK12" AND "Clark County School District" AND assessment',
#  '"engrade" AND "Clark County School District" AND assessment',
#  '"SchoolCity" AND "Clark County School District" AND assessment',
#  '"Naiku" AND "Clark County School District" AND assessment',
#  '"OARS" AND "Clark County School District" AND assessment',
#  '"oncourse " AND "Clark County School District" AND assessment',
#  '"schoolnet" AND "Clark County School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Clark County School District" AND assessment',
#  '"Edupoint" AND "Clark County School District" AND assessment',
#  '"io education" AND "Clark County School District" AND assessment',
#  '"close education" AND "Clark County School District" AND assessment',
#  '"destination knowledge" AND "Clark County School District" AND assessment',
#  '"edgED consulting" AND "Clark County School District" AND assessment',
#  '"equitable education solution" AND "Clark County School District" AND assessment',
#  '"KeyDataSystems" AND "Clark County School District" AND assessment',
#  '"IMLEA" AND "Clark County School District" AND assessment',
#  '"massp" AND "Clark County School District" AND assessment',
#  '"mindplay" AND "Clark County School District" AND assessment',
#  '"TheNationalForum" AND "Clark County School District" AND assessment',
#  '"NETWORK for quality education" AND "Clark County School District" AND assessment',
#  '"strategos group" AND "Clark County School District" AND assessment',
#  '"Texas Education Solutions " AND "Clark County School District" AND assessment',
#  'nan AND "Clark County School District" AND assessment',
#  '"Google for Education Partner" AND "Clark County School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Clark County School District" AND assessment',
#  '"QuickKey" AND "Clark County School District" AND assessment',
#  '"Certica Solutions" AND "Clark County School District" AND assessment',
#  '"STAAR Test Maker" AND "Clark County School District" AND assessment',
#  '"TEKSbank " AND "Clark County School District" AND assessment',
#  '"Five-star technology solutions" AND "Broward County Public Schools" AND assessment',
#  '"onHands Schools" AND "Broward County Public Schools" AND assessment',
#  '"Edluastic" AND "Broward County Public Schools" AND assessment',
#  '"PowerSchool" AND "Broward County Public Schools" AND assessment',
#  '"eduphoria" AND "Broward County Public Schools" AND assessment',
#  '"Otus" AND "Broward County Public Schools" AND assessment',
#  '"eDoctrina" AND "Broward County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Broward County Public Schools" AND assessment',
#  '"performance matters" AND "Broward County Public Schools" AND assessment',
#  '"illuminate education" AND "Broward County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Broward County Public Schools" AND assessment',
#  '"engrade" AND "Broward County Public Schools" AND assessment',
#  '"SchoolCity" AND "Broward County Public Schools" AND assessment',
#  '"Naiku" AND "Broward County Public Schools" AND assessment',
#  '"OARS" AND "Broward County Public Schools" AND assessment',
#  '"oncourse " AND "Broward County Public Schools" AND assessment',
#  '"schoolnet" AND "Broward County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Broward County Public Schools" AND assessment',
#  '"Edupoint" AND "Broward County Public Schools" AND assessment',
#  '"io education" AND "Broward County Public Schools" AND assessment',
#  '"close education" AND "Broward County Public Schools" AND assessment',
#  '"destination knowledge" AND "Broward County Public Schools" AND assessment',
#  '"edgED consulting" AND "Broward County Public Schools" AND assessment',
#  '"equitable education solution" AND "Broward County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Broward County Public Schools" AND assessment',
#  '"IMLEA" AND "Broward County Public Schools" AND assessment',
#  '"massp" AND "Broward County Public Schools" AND assessment',
#  '"mindplay" AND "Broward County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Broward County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Broward County Public Schools" AND assessment',
#  '"strategos group" AND "Broward County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Broward County Public Schools" AND assessment',
#  'nan AND "Broward County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Broward County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Broward County Public Schools" AND assessment',
#  '"QuickKey" AND "Broward County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Broward County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Broward County Public Schools" AND assessment',
#  '"TEKSbank " AND "Broward County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Houston Independent School District" AND assessment',
#  '"onHands Schools" AND "Houston Independent School District" AND assessment',
#  '"Edluastic" AND "Houston Independent School District" AND assessment',
#  '"PowerSchool" AND "Houston Independent School District" AND assessment',
#  '"eduphoria" AND "Houston Independent School District" AND assessment',
#  '"Otus" AND "Houston Independent School District" AND assessment',
#  '"eDoctrina" AND "Houston Independent School District" AND assessment',
#  '"Mastery Connect" AND "Houston Independent School District" AND assessment',
#  '"performance matters" AND "Houston Independent School District" AND assessment',
#  '"illuminate education" AND "Houston Independent School District" AND assessment',
#  '"FOCALPOINTK12" AND "Houston Independent School District" AND assessment',
#  '"engrade" AND "Houston Independent School District" AND assessment',
#  '"SchoolCity" AND "Houston Independent School District" AND assessment',
#  '"Naiku" AND "Houston Independent School District" AND assessment',
#  '"OARS" AND "Houston Independent School District" AND assessment',
#  '"oncourse " AND "Houston Independent School District" AND assessment',
#  '"schoolnet" AND "Houston Independent School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Houston Independent School District" AND assessment',
#  '"Edupoint" AND "Houston Independent School District" AND assessment',
#  '"io education" AND "Houston Independent School District" AND assessment',
#  '"close education" AND "Houston Independent School District" AND assessment',
#  '"destination knowledge" AND "Houston Independent School District" AND assessment',
#  '"edgED consulting" AND "Houston Independent School District" AND assessment',
#  '"equitable education solution" AND "Houston Independent School District" AND assessment',
#  '"KeyDataSystems" AND "Houston Independent School District" AND assessment',
#  '"IMLEA" AND "Houston Independent School District" AND assessment',
#  '"massp" AND "Houston Independent School District" AND assessment',
#  '"mindplay" AND "Houston Independent School District" AND assessment',
#  '"TheNationalForum" AND "Houston Independent School District" AND assessment',
#  '"NETWORK for quality education" AND "Houston Independent School District" AND assessment',
#  '"strategos group" AND "Houston Independent School District" AND assessment',
#  '"Texas Education Solutions " AND "Houston Independent School District" AND assessment',
#  'nan AND "Houston Independent School District" AND assessment',
#  '"Google for Education Partner" AND "Houston Independent School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Houston Independent School District" AND assessment',
#  '"QuickKey" AND "Houston Independent School District" AND assessment',
#  '"Certica Solutions" AND "Houston Independent School District" AND assessment',
#  '"STAAR Test Maker" AND "Houston Independent School District" AND assessment',
#  '"TEKSbank " AND "Houston Independent School District" AND assessment',
#  '"Five-star technology solutions" AND "Hillsborough County Public Schools" AND assessment',
#  '"onHands Schools" AND "Hillsborough County Public Schools" AND assessment',
#  '"Edluastic" AND "Hillsborough County Public Schools" AND assessment',
#  '"PowerSchool" AND "Hillsborough County Public Schools" AND assessment',
#  '"eduphoria" AND "Hillsborough County Public Schools" AND assessment',
#  '"Otus" AND "Hillsborough County Public Schools" AND assessment',
#  '"eDoctrina" AND "Hillsborough County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Hillsborough County Public Schools" AND assessment',
#  '"performance matters" AND "Hillsborough County Public Schools" AND assessment',
#  '"illuminate education" AND "Hillsborough County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Hillsborough County Public Schools" AND assessment',
#  '"engrade" AND "Hillsborough County Public Schools" AND assessment',
#  '"SchoolCity" AND "Hillsborough County Public Schools" AND assessment',
#  '"Naiku" AND "Hillsborough County Public Schools" AND assessment',
#  '"OARS" AND "Hillsborough County Public Schools" AND assessment',
#  '"oncourse " AND "Hillsborough County Public Schools" AND assessment',
#  '"schoolnet" AND "Hillsborough County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Hillsborough County Public Schools" AND assessment',
#  '"Edupoint" AND "Hillsborough County Public Schools" AND assessment',
#  '"io education" AND "Hillsborough County Public Schools" AND assessment',
#  '"close education" AND "Hillsborough County Public Schools" AND assessment',
#  '"destination knowledge" AND "Hillsborough County Public Schools" AND assessment',
#  '"edgED consulting" AND "Hillsborough County Public Schools" AND assessment',
#  '"equitable education solution" AND "Hillsborough County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Hillsborough County Public Schools" AND assessment',
#  '"IMLEA" AND "Hillsborough County Public Schools" AND assessment',
#  '"massp" AND "Hillsborough County Public Schools" AND assessment',
#  '"mindplay" AND "Hillsborough County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Hillsborough County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Hillsborough County Public Schools" AND assessment',
#  '"strategos group" AND "Hillsborough County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Hillsborough County Public Schools" AND assessment',
#  'nan AND "Hillsborough County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Hillsborough County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Hillsborough County Public Schools" AND assessment',
#  '"QuickKey" AND "Hillsborough County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Hillsborough County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Hillsborough County Public Schools" AND assessment',
#  '"TEKSbank " AND "Hillsborough County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Hawai_i Department of Education" AND assessment',
#  '"onHands Schools" AND "Hawai_i Department of Education" AND assessment',
#  '"Edluastic" AND "Hawai_i Department of Education" AND assessment',
#  '"PowerSchool" AND "Hawai_i Department of Education" AND assessment',
#  '"eduphoria" AND "Hawai_i Department of Education" AND assessment',
#  '"Otus" AND "Hawai_i Department of Education" AND assessment',
#  '"eDoctrina" AND "Hawai_i Department of Education" AND assessment',
#  '"Mastery Connect" AND "Hawai_i Department of Education" AND assessment',
#  '"performance matters" AND "Hawai_i Department of Education" AND assessment',
#  '"illuminate education" AND "Hawai_i Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "Hawai_i Department of Education" AND assessment',
#  '"engrade" AND "Hawai_i Department of Education" AND assessment',
#  '"SchoolCity" AND "Hawai_i Department of Education" AND assessment',
#  '"Naiku" AND "Hawai_i Department of Education" AND assessment',
#  '"OARS" AND "Hawai_i Department of Education" AND assessment',
#  '"oncourse " AND "Hawai_i Department of Education" AND assessment',
#  '"schoolnet" AND "Hawai_i Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "Hawai_i Department of Education" AND assessment',
#  '"Edupoint" AND "Hawai_i Department of Education" AND assessment',
#  '"io education" AND "Hawai_i Department of Education" AND assessment',
#  '"close education" AND "Hawai_i Department of Education" AND assessment',
#  '"destination knowledge" AND "Hawai_i Department of Education" AND assessment',
#  '"edgED consulting" AND "Hawai_i Department of Education" AND assessment',
#  '"equitable education solution" AND "Hawai_i Department of Education" AND assessment',
#  '"KeyDataSystems" AND "Hawai_i Department of Education" AND assessment',
#  '"IMLEA" AND "Hawai_i Department of Education" AND assessment',
#  '"massp" AND "Hawai_i Department of Education" AND assessment',
#  '"mindplay" AND "Hawai_i Department of Education" AND assessment',
#  '"TheNationalForum" AND "Hawai_i Department of Education" AND assessment',
#  '"NETWORK for quality education" AND "Hawai_i Department of Education" AND assessment',
#  '"strategos group" AND "Hawai_i Department of Education" AND assessment',
#  '"Texas Education Solutions " AND "Hawai_i Department of Education" AND assessment',
#  'nan AND "Hawai_i Department of Education" AND assessment',
#  '"Google for Education Partner" AND "Hawai_i Department of Education" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Hawai_i Department of Education" AND assessment',
#  '"QuickKey" AND "Hawai_i Department of Education" AND assessment',
#  '"Certica Solutions" AND "Hawai_i Department of Education" AND assessment',
#  '"STAAR Test Maker" AND "Hawai_i Department of Education" AND assessment',
#  '"TEKSbank " AND "Hawai_i Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Orange County Public Schools" AND assessment',
#  '"onHands Schools" AND "Orange County Public Schools" AND assessment',
#  '"Edluastic" AND "Orange County Public Schools" AND assessment',
#  '"PowerSchool" AND "Orange County Public Schools" AND assessment',
#  '"eduphoria" AND "Orange County Public Schools" AND assessment',
#  '"Otus" AND "Orange County Public Schools" AND assessment',
#  '"eDoctrina" AND "Orange County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Orange County Public Schools" AND assessment',
#  '"performance matters" AND "Orange County Public Schools" AND assessment',
#  '"illuminate education" AND "Orange County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Orange County Public Schools" AND assessment',
#  '"engrade" AND "Orange County Public Schools" AND assessment',
#  '"SchoolCity" AND "Orange County Public Schools" AND assessment',
#  '"Naiku" AND "Orange County Public Schools" AND assessment',
#  '"OARS" AND "Orange County Public Schools" AND assessment',
#  '"oncourse " AND "Orange County Public Schools" AND assessment',
#  '"schoolnet" AND "Orange County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Orange County Public Schools" AND assessment',
#  '"Edupoint" AND "Orange County Public Schools" AND assessment',
#  '"io education" AND "Orange County Public Schools" AND assessment',
#  '"close education" AND "Orange County Public Schools" AND assessment',
#  '"destination knowledge" AND "Orange County Public Schools" AND assessment',
#  '"edgED consulting" AND "Orange County Public Schools" AND assessment',
#  '"equitable education solution" AND "Orange County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Orange County Public Schools" AND assessment',
#  '"IMLEA" AND "Orange County Public Schools" AND assessment',
#  '"massp" AND "Orange County Public Schools" AND assessment',
#  '"mindplay" AND "Orange County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Orange County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Orange County Public Schools" AND assessment',
#  '"strategos group" AND "Orange County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Orange County Public Schools" AND assessment',
#  'nan AND "Orange County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Orange County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Orange County Public Schools" AND assessment',
#  '"QuickKey" AND "Orange County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Orange County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Orange County Public Schools" AND assessment',
#  '"TEKSbank " AND "Orange County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "School District of Palm Beach County" AND assessment',
#  '"onHands Schools" AND "School District of Palm Beach County" AND assessment',
#  '"Edluastic" AND "School District of Palm Beach County" AND assessment',
#  '"PowerSchool" AND "School District of Palm Beach County" AND assessment',
#  '"eduphoria" AND "School District of Palm Beach County" AND assessment',
#  '"Otus" AND "School District of Palm Beach County" AND assessment',
#  '"eDoctrina" AND "School District of Palm Beach County" AND assessment',
#  '"Mastery Connect" AND "School District of Palm Beach County" AND assessment',
#  '"performance matters" AND "School District of Palm Beach County" AND assessment',
#  '"illuminate education" AND "School District of Palm Beach County" AND assessment',
#  '"FOCALPOINTK12" AND "School District of Palm Beach County" AND assessment',
#  '"engrade" AND "School District of Palm Beach County" AND assessment',
#  '"SchoolCity" AND "School District of Palm Beach County" AND assessment',
#  '"Naiku" AND "School District of Palm Beach County" AND assessment',
#  '"OARS" AND "School District of Palm Beach County" AND assessment',
#  '"oncourse " AND "School District of Palm Beach County" AND assessment',
#  '"schoolnet" AND "School District of Palm Beach County" AND assessment',
#  '"Assessment Technology Incorporated" AND "School District of Palm Beach County" AND assessment',
#  '"Edupoint" AND "School District of Palm Beach County" AND assessment',
#  '"io education" AND "School District of Palm Beach County" AND assessment',
#  '"close education" AND "School District of Palm Beach County" AND assessment',
#  '"destination knowledge" AND "School District of Palm Beach County" AND assessment',
#  '"edgED consulting" AND "School District of Palm Beach County" AND assessment',
#  '"equitable education solution" AND "School District of Palm Beach County" AND assessment',
#  '"KeyDataSystems" AND "School District of Palm Beach County" AND assessment',
#  '"IMLEA" AND "School District of Palm Beach County" AND assessment',
#  '"massp" AND "School District of Palm Beach County" AND assessment',
#  '"mindplay" AND "School District of Palm Beach County" AND assessment',
#  '"TheNationalForum" AND "School District of Palm Beach County" AND assessment',
#  '"NETWORK for quality education" AND "School District of Palm Beach County" AND assessment',
#  '"strategos group" AND "School District of Palm Beach County" AND assessment',
#  '"Texas Education Solutions " AND "School District of Palm Beach County" AND assessment',
#  'nan AND "School District of Palm Beach County" AND assessment',
#  '"Google for Education Partner" AND "School District of Palm Beach County" AND assessment',
#  '"Carnegie Learning, Inc. " AND "School District of Palm Beach County" AND assessment',
#  '"QuickKey" AND "School District of Palm Beach County" AND assessment',
#  '"Certica Solutions" AND "School District of Palm Beach County" AND assessment',
#  '"STAAR Test Maker" AND "School District of Palm Beach County" AND assessment',
#  '"TEKSbank " AND "School District of Palm Beach County" AND assessment',
#  '"Five-star technology solutions" AND "Fairfax County Public Schools" AND assessment',
#  '"onHands Schools" AND "Fairfax County Public Schools" AND assessment',
#  '"Edluastic" AND "Fairfax County Public Schools" AND assessment',
#  '"PowerSchool" AND "Fairfax County Public Schools" AND assessment',
#  '"eduphoria" AND "Fairfax County Public Schools" AND assessment',
#  '"Otus" AND "Fairfax County Public Schools" AND assessment',
#  '"eDoctrina" AND "Fairfax County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Fairfax County Public Schools" AND assessment',
#  '"performance matters" AND "Fairfax County Public Schools" AND assessment',
#  '"illuminate education" AND "Fairfax County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Fairfax County Public Schools" AND assessment',
#  '"engrade" AND "Fairfax County Public Schools" AND assessment',
#  '"SchoolCity" AND "Fairfax County Public Schools" AND assessment',
#  '"Naiku" AND "Fairfax County Public Schools" AND assessment',
#  '"OARS" AND "Fairfax County Public Schools" AND assessment',
#  '"oncourse " AND "Fairfax County Public Schools" AND assessment',
#  '"schoolnet" AND "Fairfax County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Fairfax County Public Schools" AND assessment',
#  '"Edupoint" AND "Fairfax County Public Schools" AND assessment',
#  '"io education" AND "Fairfax County Public Schools" AND assessment',
#  '"close education" AND "Fairfax County Public Schools" AND assessment',
#  '"destination knowledge" AND "Fairfax County Public Schools" AND assessment',
#  '"edgED consulting" AND "Fairfax County Public Schools" AND assessment',
#  '"equitable education solution" AND "Fairfax County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Fairfax County Public Schools" AND assessment',
#  '"IMLEA" AND "Fairfax County Public Schools" AND assessment',
#  '"massp" AND "Fairfax County Public Schools" AND assessment',
#  '"mindplay" AND "Fairfax County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Fairfax County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Fairfax County Public Schools" AND assessment',
#  '"strategos group" AND "Fairfax County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Fairfax County Public Schools" AND assessment',
#  'nan AND "Fairfax County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Fairfax County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Fairfax County Public Schools" AND assessment',
#  '"QuickKey" AND "Fairfax County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Fairfax County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Fairfax County Public Schools" AND assessment',
#  '"TEKSbank " AND "Fairfax County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "School District of Philadelphia" AND assessment',
#  '"onHands Schools" AND "School District of Philadelphia" AND assessment',
#  '"Edluastic" AND "School District of Philadelphia" AND assessment',
#  '"PowerSchool" AND "School District of Philadelphia" AND assessment',
#  '"eduphoria" AND "School District of Philadelphia" AND assessment',
#  '"Otus" AND "School District of Philadelphia" AND assessment',
#  '"eDoctrina" AND "School District of Philadelphia" AND assessment',
#  '"Mastery Connect" AND "School District of Philadelphia" AND assessment',
#  '"performance matters" AND "School District of Philadelphia" AND assessment',
#  '"illuminate education" AND "School District of Philadelphia" AND assessment',
#  '"FOCALPOINTK12" AND "School District of Philadelphia" AND assessment',
#  '"engrade" AND "School District of Philadelphia" AND assessment',
#  '"SchoolCity" AND "School District of Philadelphia" AND assessment',
#  '"Naiku" AND "School District of Philadelphia" AND assessment',
#  '"OARS" AND "School District of Philadelphia" AND assessment',
#  '"oncourse " AND "School District of Philadelphia" AND assessment',
#  '"schoolnet" AND "School District of Philadelphia" AND assessment',
#  '"Assessment Technology Incorporated" AND "School District of Philadelphia" AND assessment',
#  '"Edupoint" AND "School District of Philadelphia" AND assessment',
#  '"io education" AND "School District of Philadelphia" AND assessment',
#  '"close education" AND "School District of Philadelphia" AND assessment',
#  '"destination knowledge" AND "School District of Philadelphia" AND assessment',
#  '"edgED consulting" AND "School District of Philadelphia" AND assessment',
#  '"equitable education solution" AND "School District of Philadelphia" AND assessment',
#  '"KeyDataSystems" AND "School District of Philadelphia" AND assessment',
#  '"IMLEA" AND "School District of Philadelphia" AND assessment',
#  '"massp" AND "School District of Philadelphia" AND assessment',
#  '"mindplay" AND "School District of Philadelphia" AND assessment',
#  '"TheNationalForum" AND "School District of Philadelphia" AND assessment',
#  '"NETWORK for quality education" AND "School District of Philadelphia" AND assessment',
#  '"strategos group" AND "School District of Philadelphia" AND assessment',
#  '"Texas Education Solutions " AND "School District of Philadelphia" AND assessment',
#  'nan AND "School District of Philadelphia" AND assessment',
#  '"Google for Education Partner" AND "School District of Philadelphia" AND assessment',
#  '"Carnegie Learning, Inc. " AND "School District of Philadelphia" AND assessment',
#  '"QuickKey" AND "School District of Philadelphia" AND assessment',
#  '"Certica Solutions" AND "School District of Philadelphia" AND assessment',
#  '"STAAR Test Maker" AND "School District of Philadelphia" AND assessment',
#  '"TEKSbank " AND "School District of Philadelphia" AND assessment',
#  '"Five-star technology solutions" AND "Gwinnett County Public Schools" AND assessment',
#  '"onHands Schools" AND "Gwinnett County Public Schools" AND assessment',
#  '"Edluastic" AND "Gwinnett County Public Schools" AND assessment',
#  '"PowerSchool" AND "Gwinnett County Public Schools" AND assessment',
#  '"eduphoria" AND "Gwinnett County Public Schools" AND assessment',
#  '"Otus" AND "Gwinnett County Public Schools" AND assessment',
#  '"eDoctrina" AND "Gwinnett County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Gwinnett County Public Schools" AND assessment',
#  '"performance matters" AND "Gwinnett County Public Schools" AND assessment',
#  '"illuminate education" AND "Gwinnett County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Gwinnett County Public Schools" AND assessment',
#  '"engrade" AND "Gwinnett County Public Schools" AND assessment',
#  '"SchoolCity" AND "Gwinnett County Public Schools" AND assessment',
#  '"Naiku" AND "Gwinnett County Public Schools" AND assessment',
#  '"OARS" AND "Gwinnett County Public Schools" AND assessment',
#  '"oncourse " AND "Gwinnett County Public Schools" AND assessment',
#  '"schoolnet" AND "Gwinnett County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Gwinnett County Public Schools" AND assessment',
#  '"Edupoint" AND "Gwinnett County Public Schools" AND assessment',
#  '"io education" AND "Gwinnett County Public Schools" AND assessment',
#  '"close education" AND "Gwinnett County Public Schools" AND assessment',
#  '"destination knowledge" AND "Gwinnett County Public Schools" AND assessment',
#  '"edgED consulting" AND "Gwinnett County Public Schools" AND assessment',
#  '"equitable education solution" AND "Gwinnett County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Gwinnett County Public Schools" AND assessment',
#  '"IMLEA" AND "Gwinnett County Public Schools" AND assessment',
#  '"massp" AND "Gwinnett County Public Schools" AND assessment',
#  '"mindplay" AND "Gwinnett County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Gwinnett County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Gwinnett County Public Schools" AND assessment',
#  '"strategos group" AND "Gwinnett County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Gwinnett County Public Schools" AND assessment',
#  'nan AND "Gwinnett County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Gwinnett County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Gwinnett County Public Schools" AND assessment',
#  '"QuickKey" AND "Gwinnett County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Gwinnett County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Gwinnett County Public Schools" AND assessment',
#  '"TEKSbank " AND "Gwinnett County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Dallas Independent School District" AND assessment',
#  '"onHands Schools" AND "Dallas Independent School District" AND assessment',
#  '"Edluastic" AND "Dallas Independent School District" AND assessment',
#  '"PowerSchool" AND "Dallas Independent School District" AND assessment',
#  '"eduphoria" AND "Dallas Independent School District" AND assessment',
#  '"Otus" AND "Dallas Independent School District" AND assessment',
#  '"eDoctrina" AND "Dallas Independent School District" AND assessment',
#  '"Mastery Connect" AND "Dallas Independent School District" AND assessment',
#  '"performance matters" AND "Dallas Independent School District" AND assessment',
#  '"illuminate education" AND "Dallas Independent School District" AND assessment',
#  '"FOCALPOINTK12" AND "Dallas Independent School District" AND assessment',
#  '"engrade" AND "Dallas Independent School District" AND assessment',
#  '"SchoolCity" AND "Dallas Independent School District" AND assessment',
#  '"Naiku" AND "Dallas Independent School District" AND assessment',
#  '"OARS" AND "Dallas Independent School District" AND assessment',
#  '"oncourse " AND "Dallas Independent School District" AND assessment',
#  '"schoolnet" AND "Dallas Independent School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Dallas Independent School District" AND assessment',
#  '"Edupoint" AND "Dallas Independent School District" AND assessment',
#  '"io education" AND "Dallas Independent School District" AND assessment',
#  '"close education" AND "Dallas Independent School District" AND assessment',
#  '"destination knowledge" AND "Dallas Independent School District" AND assessment',
#  '"edgED consulting" AND "Dallas Independent School District" AND assessment',
#  '"equitable education solution" AND "Dallas Independent School District" AND assessment',
#  '"KeyDataSystems" AND "Dallas Independent School District" AND assessment',
#  '"IMLEA" AND "Dallas Independent School District" AND assessment',
#  '"massp" AND "Dallas Independent School District" AND assessment',
#  '"mindplay" AND "Dallas Independent School District" AND assessment',
#  '"TheNationalForum" AND "Dallas Independent School District" AND assessment',
#  '"NETWORK for quality education" AND "Dallas Independent School District" AND assessment',
#  '"strategos group" AND "Dallas Independent School District" AND assessment',
#  '"Texas Education Solutions " AND "Dallas Independent School District" AND assessment',
#  'nan AND "Dallas Independent School District" AND assessment',
#  '"Google for Education Partner" AND "Dallas Independent School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Dallas Independent School District" AND assessment',
#  '"QuickKey" AND "Dallas Independent School District" AND assessment',
#  '"Certica Solutions" AND "Dallas Independent School District" AND assessment',
#  '"STAAR Test Maker" AND "Dallas Independent School District" AND assessment',
#  '"TEKSbank " AND "Dallas Independent School District" AND assessment',
#  '"Five-star technology solutions" AND "Wake County Public School System" AND assessment',
#  '"onHands Schools" AND "Wake County Public School System" AND assessment',
#  '"Edluastic" AND "Wake County Public School System" AND assessment',
#  '"PowerSchool" AND "Wake County Public School System" AND assessment',
#  '"eduphoria" AND "Wake County Public School System" AND assessment',
#  '"Otus" AND "Wake County Public School System" AND assessment',
#  '"eDoctrina" AND "Wake County Public School System" AND assessment',
#  '"Mastery Connect" AND "Wake County Public School System" AND assessment',
#  '"performance matters" AND "Wake County Public School System" AND assessment',
#  '"illuminate education" AND "Wake County Public School System" AND assessment',
#  '"FOCALPOINTK12" AND "Wake County Public School System" AND assessment',
#  '"engrade" AND "Wake County Public School System" AND assessment',
#  '"SchoolCity" AND "Wake County Public School System" AND assessment',
#  '"Naiku" AND "Wake County Public School System" AND assessment',
#  '"OARS" AND "Wake County Public School System" AND assessment',
#  '"oncourse " AND "Wake County Public School System" AND assessment',
#  '"schoolnet" AND "Wake County Public School System" AND assessment',
# ...
#  '"Otus" AND "Prince George\'s County Public Schools" AND assessment',
#  '"eDoctrina" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Prince George\'s County Public Schools" AND assessment',
#  '"performance matters" AND "Prince George\'s County Public Schools" AND assessment',
#  '"illuminate education" AND "Prince George\'s County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Prince George\'s County Public Schools" AND assessment',
#  '"engrade" AND "Prince George\'s County Public Schools" AND assessment',
#  '"SchoolCity" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Naiku" AND "Prince George\'s County Public Schools" AND assessment',
#  '"OARS" AND "Prince George\'s County Public Schools" AND assessment',
#  '"oncourse " AND "Prince George\'s County Public Schools" AND assessment',
#  '"schoolnet" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Edupoint" AND "Prince George\'s County Public Schools" AND assessment',
#  '"io education" AND "Prince George\'s County Public Schools" AND assessment',
#  '"close education" AND "Prince George\'s County Public Schools" AND assessment',
#  '"destination knowledge" AND "Prince George\'s County Public Schools" AND assessment',
#  '"edgED consulting" AND "Prince George\'s County Public Schools" AND assessment',
#  '"equitable education solution" AND "Prince George\'s County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Prince George\'s County Public Schools" AND assessment',
#  '"IMLEA" AND "Prince George\'s County Public Schools" AND assessment',
#  '"massp" AND "Prince George\'s County Public Schools" AND assessment',
#  '"mindplay" AND "Prince George\'s County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Prince George\'s County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Prince George\'s County Public Schools" AND assessment',
#  '"strategos group" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Prince George\'s County Public Schools" AND assessment',
#  'nan AND "Prince George\'s County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Prince George\'s County Public Schools" AND assessment',
#  '"QuickKey" AND "Prince George\'s County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Prince George\'s County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Prince George\'s County Public Schools" AND assessment',
#  '"TEKSbank " AND "Prince George\'s County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Duval County Public Schools" AND assessment',
#  '"onHands Schools" AND "Duval County Public Schools" AND assessment',
#  '"Edluastic" AND "Duval County Public Schools" AND assessment',
#  '"PowerSchool" AND "Duval County Public Schools" AND assessment',
#  '"eduphoria" AND "Duval County Public Schools" AND assessment',
#  '"Otus" AND "Duval County Public Schools" AND assessment',
#  '"eDoctrina" AND "Duval County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Duval County Public Schools" AND assessment',
#  '"performance matters" AND "Duval County Public Schools" AND assessment',
#  '"illuminate education" AND "Duval County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Duval County Public Schools" AND assessment',
#  '"engrade" AND "Duval County Public Schools" AND assessment',
#  '"SchoolCity" AND "Duval County Public Schools" AND assessment',
#  '"Naiku" AND "Duval County Public Schools" AND assessment',
#  '"OARS" AND "Duval County Public Schools" AND assessment',
#  '"oncourse " AND "Duval County Public Schools" AND assessment',
#  '"schoolnet" AND "Duval County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Duval County Public Schools" AND assessment',
#  '"Edupoint" AND "Duval County Public Schools" AND assessment',
#  '"io education" AND "Duval County Public Schools" AND assessment',
#  '"close education" AND "Duval County Public Schools" AND assessment',
#  '"destination knowledge" AND "Duval County Public Schools" AND assessment',
#  '"edgED consulting" AND "Duval County Public Schools" AND assessment',
#  '"equitable education solution" AND "Duval County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Duval County Public Schools" AND assessment',
#  '"IMLEA" AND "Duval County Public Schools" AND assessment',
#  '"massp" AND "Duval County Public Schools" AND assessment',
#  '"mindplay" AND "Duval County Public Schools" AND assessment',
#  '"TheNationalForum" AND "Duval County Public Schools" AND assessment',
#  '"NETWORK for quality education" AND "Duval County Public Schools" AND assessment',
#  '"strategos group" AND "Duval County Public Schools" AND assessment',
#  '"Texas Education Solutions " AND "Duval County Public Schools" AND assessment',
#  'nan AND "Duval County Public Schools" AND assessment',
#  '"Google for Education Partner" AND "Duval County Public Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Duval County Public Schools" AND assessment',
#  '"QuickKey" AND "Duval County Public Schools" AND assessment',
#  '"Certica Solutions" AND "Duval County Public Schools" AND assessment',
#  '"STAAR Test Maker" AND "Duval County Public Schools" AND assessment',
#  '"TEKSbank " AND "Duval County Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Memphis City Schools" AND assessment',
#  '"onHands Schools" AND "Memphis City Schools" AND assessment',
#  '"Edluastic" AND "Memphis City Schools" AND assessment',
#  '"PowerSchool" AND "Memphis City Schools" AND assessment',
#  '"eduphoria" AND "Memphis City Schools" AND assessment',
#  '"Otus" AND "Memphis City Schools" AND assessment',
#  '"eDoctrina" AND "Memphis City Schools" AND assessment',
#  '"Mastery Connect" AND "Memphis City Schools" AND assessment',
#  '"performance matters" AND "Memphis City Schools" AND assessment',
#  '"illuminate education" AND "Memphis City Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Memphis City Schools" AND assessment',
#  '"engrade" AND "Memphis City Schools" AND assessment',
#  '"SchoolCity" AND "Memphis City Schools" AND assessment',
#  '"Naiku" AND "Memphis City Schools" AND assessment',
#  '"OARS" AND "Memphis City Schools" AND assessment',
#  '"oncourse " AND "Memphis City Schools" AND assessment',
#  '"schoolnet" AND "Memphis City Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Memphis City Schools" AND assessment',
#  '"Edupoint" AND "Memphis City Schools" AND assessment',
#  '"io education" AND "Memphis City Schools" AND assessment',
#  '"close education" AND "Memphis City Schools" AND assessment',
#  '"destination knowledge" AND "Memphis City Schools" AND assessment',
#  '"edgED consulting" AND "Memphis City Schools" AND assessment',
#  '"equitable education solution" AND "Memphis City Schools" AND assessment',
#  '"KeyDataSystems" AND "Memphis City Schools" AND assessment',
#  '"IMLEA" AND "Memphis City Schools" AND assessment',
#  '"massp" AND "Memphis City Schools" AND assessment',
#  '"mindplay" AND "Memphis City Schools" AND assessment',
#  '"TheNationalForum" AND "Memphis City Schools" AND assessment',
#  '"NETWORK for quality education" AND "Memphis City Schools" AND assessment',
#  '"strategos group" AND "Memphis City Schools" AND assessment',
#  '"Texas Education Solutions " AND "Memphis City Schools" AND assessment',
#  'nan AND "Memphis City Schools" AND assessment',
#  '"Google for Education Partner" AND "Memphis City Schools" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Memphis City Schools" AND assessment',
#  '"QuickKey" AND "Memphis City Schools" AND assessment',
#  '"Certica Solutions" AND "Memphis City Schools" AND assessment',
#  '"STAAR Test Maker" AND "Memphis City Schools" AND assessment',
#  '"TEKSbank " AND "Memphis City Schools" AND assessment',
#  '"Five-star technology solutions" AND "Cobb County School District" AND assessment',
#  '"onHands Schools" AND "Cobb County School District" AND assessment',
#  '"Edluastic" AND "Cobb County School District" AND assessment',
#  '"PowerSchool" AND "Cobb County School District" AND assessment',
#  '"eduphoria" AND "Cobb County School District" AND assessment',
#  '"Otus" AND "Cobb County School District" AND assessment',
#  '"eDoctrina" AND "Cobb County School District" AND assessment',
#  '"Mastery Connect" AND "Cobb County School District" AND assessment',
#  '"performance matters" AND "Cobb County School District" AND assessment',
#  '"illuminate education" AND "Cobb County School District" AND assessment',
#  '"FOCALPOINTK12" AND "Cobb County School District" AND assessment',
#  '"engrade" AND "Cobb County School District" AND assessment',
#  '"SchoolCity" AND "Cobb County School District" AND assessment',
#  '"Naiku" AND "Cobb County School District" AND assessment',
#  '"OARS" AND "Cobb County School District" AND assessment',
#  '"oncourse " AND "Cobb County School District" AND assessment',
#  '"schoolnet" AND "Cobb County School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Cobb County School District" AND assessment',
#  '"Edupoint" AND "Cobb County School District" AND assessment',
#  '"io education" AND "Cobb County School District" AND assessment',
#  '"close education" AND "Cobb County School District" AND assessment',
#  '"destination knowledge" AND "Cobb County School District" AND assessment',
#  '"edgED consulting" AND "Cobb County School District" AND assessment',
#  '"equitable education solution" AND "Cobb County School District" AND assessment',
#  '"KeyDataSystems" AND "Cobb County School District" AND assessment',
#  '"IMLEA" AND "Cobb County School District" AND assessment',
#  '"massp" AND "Cobb County School District" AND assessment',
#  '"mindplay" AND "Cobb County School District" AND assessment',
#  '"TheNationalForum" AND "Cobb County School District" AND assessment',
#  '"NETWORK for quality education" AND "Cobb County School District" AND assessment',
#  '"strategos group" AND "Cobb County School District" AND assessment',
#  '"Texas Education Solutions " AND "Cobb County School District" AND assessment',
#  'nan AND "Cobb County School District" AND assessment',
#  '"Google for Education Partner" AND "Cobb County School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Cobb County School District" AND assessment',
#  '"QuickKey" AND "Cobb County School District" AND assessment',
#  '"Certica Solutions" AND "Cobb County School District" AND assessment',
#  '"STAAR Test Maker" AND "Cobb County School District" AND assessment',
#  '"TEKSbank " AND "Cobb County School District" AND assessment',
#  '"Five-star technology solutions" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"onHands Schools" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Edluastic" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"PowerSchool" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"eduphoria" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Otus" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"eDoctrina" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Mastery Connect" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"performance matters" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"illuminate education" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"FOCALPOINTK12" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"engrade" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"SchoolCity" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Naiku" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"OARS" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"oncourse " AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"schoolnet" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Edupoint" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"io education" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"close education" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"destination knowledge" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"edgED consulting" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"equitable education solution" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"KeyDataSystems" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"IMLEA" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"massp" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"mindplay" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"TheNationalForum" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"NETWORK for quality education" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"strategos group" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Texas Education Solutions " AND "Cypress-Fairbanks Independent School District" AND assessment',
#  'nan AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Google for Education Partner" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Carnegie Learning, Inc. " AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"QuickKey" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Certica Solutions" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"STAAR Test Maker" AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"TEKSbank " AND "Cypress-Fairbanks Independent School District" AND assessment',
#  '"Five-star technology solutions" AND "Baltimore County Public Schools" AND assessment',
#  '"onHands Schools" AND "Baltimore County Public Schools" AND assessment',
#  '"Edluastic" AND "Baltimore County Public Schools" AND assessment',
#  '"PowerSchool" AND "Baltimore County Public Schools" AND assessment',
#  '"eduphoria" AND "Baltimore County Public Schools" AND assessment',
#  '"Otus" AND "Baltimore County Public Schools" AND assessment',
#  '"eDoctrina" AND "Baltimore County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Baltimore County Public Schools" AND assessment',
#  '"performance matters" AND "Baltimore County Public Schools" AND assessment',
#  '"illuminate education" AND "Baltimore County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Baltimore County Public Schools" AND assessment',
#  '"engrade" AND "Baltimore County Public Schools" AND assessment',
#  '"SchoolCity" AND "Baltimore County Public Schools" AND assessment',
#  '"Naiku" AND "Baltimore County Public Schools" AND assessment',
#  '"OARS" AND "Baltimore County Public Schools" AND assessment',
#  '"oncourse " AND "Baltimore County Public Schools" AND assessment',
#  '"schoolnet" AND "Baltimore County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Baltimore County Public Schools" AND assessment',
#  '"Edupoint" AND "Baltimore County Public Schools" AND assessment',
#  '"io education" AND "Baltimore County Public Schools" AND assessment',
#  '"close education" AND "Baltimore County Public Schools" AND assessment',
#  '"destination knowledge" AND "Baltimore County Public Schools" AND assessment',
#  '"edgED consulting" AND "Baltimore County Public Schools" AND assessment',
#  '"equitable education solution" AND "Baltimore County Public Schools" AND assessment',
#  '"KeyDataSystems" AND "Baltimore County Public Schools" AND assessment',
#  ...]

# %%
returned_urls = []
phrase = []
for item in search_terms:
    for url in search(item, start = 1, stop = 2, num = 1):
        returned = url
        returned_urls.append(url)
        phrase.append(item)
returned_urls
phrase
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-86ec252dd6ba> in <module>()
#       2 phrase = []
#       3 for item in search_terms:
# ----> 4     for url in search(item, start = 1, stop = 2, num = 1):
#       5         returned = url
#       6         returned_urls.append(url)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/google/__init__.py in search(query, tld, lang, tbs, safe, num, start, stop, pause, only_standard, extra_params, tpe, user_agent)
#     302
#     303         # Request the Google Search results page.
# --> 304         html = get_page(url)
#     305
#     306         # Parse the response and process every anchored URL.
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/google/__init__.py in get_page(url, user_agent)
#     119     request.add_header('User-Agent', USER_AGENT)
#     120     cookie_jar.add_cookie_header(request)
# --> 121     response = urlopen(request)
#     122     cookie_jar.extract_cookies(response, request)
#     123     html = response.read()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     502             http_err = 0
#     503         args = (dict, proto, meth_name) + args
# --> 504         result = self._call_chain(*args)
#     505         if result:
#     506             return result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     694         fp.close()
#     695
# --> 696         return self.parent.open(new, timeout=req.timeout)
#     697
#     698     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     508         if http_err:
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#     512 # XXX probably also want an abstract factory that knows when it makes
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     588 class HTTPDefaultErrorHandler(BaseHandler):
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#     592 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
returned_urls
# Out:
# ['https://www.pinterest.com/pin/512284526337160384/',
#  'http://www.p12.nysed.gov/accountability/T1/titleia/sig1003g/1112/docs/AppendixBEFG.pdf',
#  'https://www.linkedin.com/jobs/search?keywords=Director+Developer&locationId=us:0&start=400&count=25&applyLogin=false',
#  'https://www.imsglobal.org/leadership/technical-advisory-board-tab',
#  'https://www.regents.nysed.gov/common/regents/files/215p12a3.pdf',
#  'http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M189.pdf',
#  'http://www.generationready.com/category/press-release/',
#  'http://www.ccsso.org/Documents/2016/NCSA/Reg%20List%206%2016%2016%20public.xls',
#  'http://jacobhancock99.blogspot.com/2015/',
#  'http://schools.nyc.gov/NR/rdonlyres/0A3F0EF9-CDB5-42AE-9D7D-A9B5201A436B/165486/Forthewebsite.docx',
#  'https://2017learningimpactleadershipinst.sched.com/directory/attendees',
#  'https://thejournal.com/~/media/38AF1E431DA24A84A03970C63D2DA479.pdf',
#  'http://schools.nyc.gov/documents/oaosi/cep/2014-15/cep_K352.pdf',
#  'http://schools.nyc.gov/documents/oaosi/cep/2015-16/cep_Q141.pdf',
#  'https://www.facebook.com/jody.jepson.9',
#  'http://pages.nxtbook.com/nxtbooks/pmg/da0711/offline/pmg_da0711.pdf',
#  'http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_X131.pdf',
#  'https://issuu.com/rockeymoore/docs/2020-vision-report',
#  'https://www.glassdoor.com/Job/new-york-project-contracts-administrator-jobs-SRCH_IL.0,8_IC1132348_KO9,40_IP22.htm',
#  'http://online.ccsso.org/iweb/upload/CCSSOLegislativeConference2015Agenda.pdf',
#  'https://www.pinterest.com/pin/174444185546043291/',
#  'http://mymassp.com/files/redesigned-sat-k12-using-scores-and-reporting-inform-instruction.pdf',
#  'http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M102.pdf',
#  'https://patriotmongoose.wordpress.com/2016/10/03/education-groups-that-gates-is-donating-to/',
#  'http://schools.nyc.gov/Accountability/tools/survey/Parentdirectionshaitiancreoled75.htm?mo=1&yr=2017',
#  'http://www.edtechupdate.com/google/professional-learning/',
#  'https://marketbrief.edweek.org/wp-content/uploads/2017/02/Noodle-Markets-Report-3-Math-Grades-6-8.pdf',
#  'http://dotixo.com/search/free+technology+for+teachers+crello',
#  'http://www.ccsso.org/Documents/2017/NCSA/Registration%20List%2006192017%20ext.xls',
#  'https://thejournal.com/articles/list/news2.aspx?sc_lang%5Cu003de',
#  'https://cms.bsu.edu/-/media/www/departmentalcontent/teachers/pdfs/new%20cv/salloum%20cv%209%209%2016.pdf?la=en',
#  'http://www.laschoolboard.org/sites/default/files/Tab6.SternRenew.pdf',
#  'https://learningforward.org/docs/pdf/annual07program.pdf',
#  'https://www.redfin.com/CA/Los-Angeles/1216-N-Sycamore-Ave-90038/home/7107565',
#  'http://www.p12.nysed.gov/oisr/Rochester-city-sdschool-41.pdf',
#  'https://www.linkedin.com/in/devera-educator',
#  'http://www.performancematters.com/webinar-the-importance-of-fair-reliable-valid-and-defensible-observations/',
#  'https://www.illuminateed.com/blog/category/case-study/',
#  'https://www.edsurge.com/sitemap_wiki.xml',
#  'https://sunnybraeavenueelementary.files.wordpress.com/2015/07/assessments.pdf']

# %%
phrase
# Out:
# ['"Five-star technology solutions" AND "New York City Department of Education" AND assessment',
#  '"PowerSchool" AND "New York City Department of Education" AND assessment',
#  '"eduphoria" AND "New York City Department of Education" AND assessment',
#  '"Otus" AND "New York City Department of Education" AND assessment',
#  '"eDoctrina" AND "New York City Department of Education" AND assessment',
#  '"Mastery Connect" AND "New York City Department of Education" AND assessment',
#  '"performance matters" AND "New York City Department of Education" AND assessment',
#  '"illuminate education" AND "New York City Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "New York City Department of Education" AND assessment',
#  '"engrade" AND "New York City Department of Education" AND assessment',
#  '"SchoolCity" AND "New York City Department of Education" AND assessment',
#  '"Naiku" AND "New York City Department of Education" AND assessment',
#  '"OARS" AND "New York City Department of Education" AND assessment',
#  '"schoolnet" AND "New York City Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "New York City Department of Education" AND assessment',
#  '"Edupoint" AND "New York City Department of Education" AND assessment',
#  '"io education" AND "New York City Department of Education" AND assessment',
#  '"close education" AND "New York City Department of Education" AND assessment',
#  '"destination knowledge" AND "New York City Department of Education" AND assessment',
#  '"edgED consulting" AND "New York City Department of Education" AND assessment',
#  '"IMLEA" AND "New York City Department of Education" AND assessment',
#  '"massp" AND "New York City Department of Education" AND assessment',
#  '"mindplay" AND "New York City Department of Education" AND assessment',
#  '"NETWORK for quality education" AND "New York City Department of Education" AND assessment',
#  'nan AND "New York City Department of Education" AND assessment',
#  '"Google for Education Partner" AND "New York City Department of Education" AND assessment',
#  '"Carnegie Learning, Inc. " AND "New York City Department of Education" AND assessment',
#  '"QuickKey" AND "New York City Department of Education" AND assessment',
#  '"Certica Solutions" AND "New York City Department of Education" AND assessment',
#  '"STAAR Test Maker" AND "New York City Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Los Angeles Unified School District" AND assessment',
#  '"PowerSchool" AND "Los Angeles Unified School District" AND assessment',
#  '"eduphoria" AND "Los Angeles Unified School District" AND assessment',
#  '"Otus" AND "Los Angeles Unified School District" AND assessment',
#  '"eDoctrina" AND "Los Angeles Unified School District" AND assessment',
#  '"Mastery Connect" AND "Los Angeles Unified School District" AND assessment',
#  '"performance matters" AND "Los Angeles Unified School District" AND assessment',
#  '"illuminate education" AND "Los Angeles Unified School District" AND assessment',
#  '"FOCALPOINTK12" AND "Los Angeles Unified School District" AND assessment',
#  '"engrade" AND "Los Angeles Unified School District" AND assessment']

# %%
# put the two lists into a dataframe
returned_list = pd.DataFrame (
{
 'returned_urls': returned_urls,
 'phrase': phrase
    
})

# %%
pd.set_option("display.max_colwidth", 999)
returned_list
# Out:
#                                                                                              phrase  \
# 0       "Five-star technology solutions" AND "New York City Department of Education" AND assessment
# 1                          "PowerSchool" AND "New York City Department of Education" AND assessment
# 2                            "eduphoria" AND "New York City Department of Education" AND assessment
# 3                                 "Otus" AND "New York City Department of Education" AND assessment
# 4                            "eDoctrina" AND "New York City Department of Education" AND assessment
# 5                      "Mastery Connect" AND "New York City Department of Education" AND assessment
# 6                  "performance matters" AND "New York City Department of Education" AND assessment
# 7                 "illuminate education" AND "New York City Department of Education" AND assessment
# 8                        "FOCALPOINTK12" AND "New York City Department of Education" AND assessment
# 9                              "engrade" AND "New York City Department of Education" AND assessment
# 10                          "SchoolCity" AND "New York City Department of Education" AND assessment
# 11                               "Naiku" AND "New York City Department of Education" AND assessment
# 12                                "OARS" AND "New York City Department of Education" AND assessment
# 13                           "schoolnet" AND "New York City Department of Education" AND assessment
# 14  "Assessment Technology Incorporated" AND "New York City Department of Education" AND assessment
# 15                            "Edupoint" AND "New York City Department of Education" AND assessment
# 16                        "io education" AND "New York City Department of Education" AND assessment
# 17                     "close education" AND "New York City Department of Education" AND assessment
# 18               "destination knowledge" AND "New York City Department of Education" AND assessment
# 19                    "edgED consulting" AND "New York City Department of Education" AND assessment
# 20                               "IMLEA" AND "New York City Department of Education" AND assessment
# 21                               "massp" AND "New York City Department of Education" AND assessment
# 22                            "mindplay" AND "New York City Department of Education" AND assessment
# 23       "NETWORK for quality education" AND "New York City Department of Education" AND assessment
# 24                                   nan AND "New York City Department of Education" AND assessment
# 25        "Google for Education Partner" AND "New York City Department of Education" AND assessment
# 26            "Carnegie Learning, Inc. " AND "New York City Department of Education" AND assessment
# 27                            "QuickKey" AND "New York City Department of Education" AND assessment
# 28                   "Certica Solutions" AND "New York City Department of Education" AND assessment
# 29                    "STAAR Test Maker" AND "New York City Department of Education" AND assessment
# 30        "Five-star technology solutions" AND "Los Angeles Unified School District" AND assessment
# 31                           "PowerSchool" AND "Los Angeles Unified School District" AND assessment
# 32                             "eduphoria" AND "Los Angeles Unified School District" AND assessment
# 33                                  "Otus" AND "Los Angeles Unified School District" AND assessment
# 34                             "eDoctrina" AND "Los Angeles Unified School District" AND assessment
# 35                       "Mastery Connect" AND "Los Angeles Unified School District" AND assessment
# 36                   "performance matters" AND "Los Angeles Unified School District" AND assessment
# 37                  "illuminate education" AND "Los Angeles Unified School District" AND assessment
# 38                         "FOCALPOINTK12" AND "Los Angeles Unified School District" AND assessment
# 39                               "engrade" AND "Los Angeles Unified School District" AND assessment
#
#                                                                                                            returned_urls
# 0                                                                      https://www.pinterest.com/pin/512284526337160384/
# 1                                 http://www.p12.nysed.gov/accountability/T1/titleia/sig1003g/1112/docs/AppendixBEFG.pdf
# 2   https://www.linkedin.com/jobs/search?keywords=Director+Developer&locationId=us:0&start=400&count=25&applyLogin=false
# 3                                                      https://www.imsglobal.org/leadership/technical-advisory-board-tab
# 4                                                        https://www.regents.nysed.gov/common/regents/files/215p12a3.pdf
# 5                                                        http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M189.pdf
# 6                                                                 http://www.generationready.com/category/press-release/
# 7                                         http://www.ccsso.org/Documents/2016/NCSA/Reg%20List%206%2016%2016%20public.xls
# 8                                                                               http://jacobhancock99.blogspot.com/2015/
# 9                     http://schools.nyc.gov/NR/rdonlyres/0A3F0EF9-CDB5-42AE-9D7D-A9B5201A436B/165486/Forthewebsite.docx
# 10                                                https://2017learningimpactleadershipinst.sched.com/directory/attendees
# 11                                                   https://thejournal.com/~/media/38AF1E431DA24A84A03970C63D2DA479.pdf
# 12                                                       http://schools.nyc.gov/documents/oaosi/cep/2014-15/cep_K352.pdf
# 13                                                       http://schools.nyc.gov/documents/oaosi/cep/2015-16/cep_Q141.pdf
# 14                                                                                https://www.facebook.com/jody.jepson.9
# 15                                                   http://pages.nxtbook.com/nxtbooks/pmg/da0711/offline/pmg_da0711.pdf
# 16                                                       http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_X131.pdf
# 17                                                                 https://issuu.com/rockeymoore/docs/2020-vision-report
# 18     https://www.glassdoor.com/Job/new-york-project-contracts-administrator-jobs-SRCH_IL.0,8_IC1132348_KO9,40_IP22.htm
# 19                                          http://online.ccsso.org/iweb/upload/CCSSOLegislativeConference2015Agenda.pdf
# 20                                                                     https://www.pinterest.com/pin/174444185546043291/
# 21                         http://mymassp.com/files/redesigned-sat-k12-using-scores-and-reporting-inform-instruction.pdf
# 22                                                       http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M102.pdf
# 23                          https://patriotmongoose.wordpress.com/2016/10/03/education-groups-that-gates-is-donating-to/
# 24                  http://schools.nyc.gov/Accountability/tools/survey/Parentdirectionshaitiancreoled75.htm?mo=1&yr=2017
# 25                                                             http://www.edtechupdate.com/google/professional-learning/
# 26                 https://marketbrief.edweek.org/wp-content/uploads/2017/02/Noodle-Markets-Report-3-Math-Grades-6-8.pdf
# 27                                                          http://dotixo.com/search/free+technology+for+teachers+crello
# 28                                     http://www.ccsso.org/Documents/2017/NCSA/Registration%20List%2006192017%20ext.xls
# 29                                                      https://thejournal.com/articles/list/news2.aspx?sc_lang%5Cu003de
# 30        https://cms.bsu.edu/-/media/www/departmentalcontent/teachers/pdfs/new%20cv/salloum%20cv%209%209%2016.pdf?la=en
# 31                                                  http://www.laschoolboard.org/sites/default/files/Tab6.SternRenew.pdf
# 32                                                              https://learningforward.org/docs/pdf/annual07program.pdf
# 33                                          https://www.redfin.com/CA/Los-Angeles/1216-N-Sycamore-Ave-90038/home/7107565
# 34                                                          http://www.p12.nysed.gov/oisr/Rochester-city-sdschool-41.pdf
# 35                                                                           https://www.linkedin.com/in/devera-educator
# 36          http://www.performancematters.com/webinar-the-importance-of-fair-reliable-valid-and-defensible-observations/
# 37                                                                https://www.illuminateed.com/blog/category/case-study/
# 38                                                                              https://www.edsurge.com/sitemap_wiki.xml
# 39                                         https://sunnybraeavenueelementary.files.wordpress.com/2015/07/assessments.pdf

# %% [markdown]
# ### Examples
#
# "eDoctrina" AND "New York City Department of Education" AND assessment	(KeyData System)
# https://www.regents.nysed.gov/common/regents/files/215p12a3.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# "Mastery Connect" AND "New York City Department of Education" AND assessment  <p>
#
# http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M189.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# "io education" AND "New York City Department of Education" AND assessment
# http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_X131.pdf

# %% [markdown]
# ![image.png](attachment:image.png)
