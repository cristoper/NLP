# %%
import pandas as pd
from google import search

# %% [markdown]
# # Methodology Overview: The purpose of this document is flesh out the methods around RQ 1.

# %% [markdown]
# RQ 1 states: What is the scope and nature of the network between item bank vendors and assessment system vendors? <p>
# Current methods state: The data for RQ 1 is obtained from publically available information on the internet or provided by school district staff and/or assessment platform vendor upon request (e.g., see Forrester, 2014 for a technical report provided upon request). To constrain the scope of this part of the study, we are focusing attention on existing school district assessment management system vendors among the 50 largest public school districts in the United States.

# %% [markdown]
# # Overview of the proposed methodology

# %% [markdown]
# The proposed methodology involves the following steps:
# 1. Manually gather information of item banks and their associated platform partners (KeyData Systems example presented below).
# 2. Identify the top 50 school districts in the country, and place these in a list.
# 3. Programmatically create search terms that will search for the following:  ItemBankPartner AND SchoolDistrict AND "assessment"
# 4. Automatically query either Google or Bing (both pose unique problems), and have the first (most relevant) url returned.
# 5. Compile all returned urls, and visual inspect urls to furter explore any that are from any one of the following three sources: (1) The school district's website, (2) an official document from the school district, (3) the platform's website.
# 6. Document when a school district or a vendor website explicity state that the platform is used for a given school district.

# %% [markdown]
# ## Step 1

# %% [markdown]
# Manually gather information of item banks, and their associated platform partners (KeyData Systems example presented below):

# %%
item_partners = pd.read_csv("/Users/amyburkhardt/Dropbox/ItemBankInvestigation/ItemBank_Network.csv")
item_partners['ItemBankPartners'] = '"' + item_partners['ItemBankPartners'] + '"' # quotes used for google query
item_partners[['ItemBank', 'ItemBankPartners']]
# Out:
#           ItemBank                      ItemBankPartners
# 0   KeyDataSystems      "Five-star technology solutions"
# 1   KeyDataSystems                     "onHands Schools"
# 2   KeyDataSystems                           "Edluastic"
# 3   KeyDataSystems                         "PowerSchool"
# 4   KeyDataSystems                           "eduphoria"
# 5   KeyDataSystems                                "Otus"
# 6   KeyDataSystems                           "eDoctrina"
# 7   KeyDataSystems                     "Mastery Connect"
# 8   KeyDataSystems                 "performance matters"
# 9   KeyDataSystems                "illuminate education"
# 10  KeyDataSystems                       "FOCALPOINTK12"
# 11  KeyDataSystems                             "engrade"
# 12  KeyDataSystems                          "SchoolCity"
# 13  KeyDataSystems                               "Naiku"
# 14  KeyDataSystems                                "OARS"
# 15  KeyDataSystems                           "oncourse "
# 16  KeyDataSystems                           "schoolnet"
# 17  KeyDataSystems  "Assessment Technology Incorporated"
# 18  KeyDataSystems                            "Edupoint"
# 19  KeyDataSystems                        "io education"

# %% [markdown]
# ## Step 2

# %% [markdown]
# Identify the top 50 school districts in the country (source: Wikipedia):

# %%
schools = pd.read_csv("/Users/amyburkhardt/Dropbox/ItemBankInvestigation/schoolDistricts.csv")
schools['School District'] = '"' + schools['School District'] + '"'
schools.head(15)
# Out:
#                             School District
# 0   "New York City Department of Education"
# 1     "Los Angeles Unified School District"
# 2     "Puerto Rico Department of Education"
# 3                  "Chicago Public Schools"
# 4        "Miami-Dade County Public Schools"
# 5            "Clark County School District"
# 6           "Broward County Public Schools"
# 7     "Houston Independent School District"
# 8      "Hillsborough County Public Schools"
# 9         "Hawai_i Department of Education"
# 10           "Orange County Public Schools"
# 11   "School District of Palm Beach County"
# 12          "Fairfax County Public Schools"
# 13        "School District of Philadelphia"
# 14         "Gwinnett County Public Schools"

# %% [markdown]
# ## Step 3

# %% [markdown]
# Programmatically create search terms that will search for the following:  ItemBankPartner AND SchoolDistrict AND "assessment". Note, below are 1000 unique search terms that are automatically generated, but only the top 100 are printed out.

# %%
search_terms = []
for school in schools['School District']:
    for ven in item_partners['ItemBankPartners']: 
        term = "{} AND {} AND assessment".format(ven, school)
        search_terms.append(term)
search_terms[:100]
# Out:
# ['"Five-star technology solutions" AND "New York City Department of Education" AND assessment',
#  '"onHands Schools" AND "New York City Department of Education" AND assessment',
#  '"Edluastic" AND "New York City Department of Education" AND assessment',
#  '"PowerSchool" AND "New York City Department of Education" AND assessment',
#  '"eduphoria" AND "New York City Department of Education" AND assessment',
#  '"Otus" AND "New York City Department of Education" AND assessment',
#  '"eDoctrina" AND "New York City Department of Education" AND assessment',
#  '"Mastery Connect" AND "New York City Department of Education" AND assessment',
#  '"performance matters" AND "New York City Department of Education" AND assessment',
#  '"illuminate education" AND "New York City Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "New York City Department of Education" AND assessment',
#  '"engrade" AND "New York City Department of Education" AND assessment',
#  '"SchoolCity" AND "New York City Department of Education" AND assessment',
#  '"Naiku" AND "New York City Department of Education" AND assessment',
#  '"OARS" AND "New York City Department of Education" AND assessment',
#  '"oncourse " AND "New York City Department of Education" AND assessment',
#  '"schoolnet" AND "New York City Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "New York City Department of Education" AND assessment',
#  '"Edupoint" AND "New York City Department of Education" AND assessment',
#  '"io education" AND "New York City Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Los Angeles Unified School District" AND assessment',
#  '"onHands Schools" AND "Los Angeles Unified School District" AND assessment',
#  '"Edluastic" AND "Los Angeles Unified School District" AND assessment',
#  '"PowerSchool" AND "Los Angeles Unified School District" AND assessment',
#  '"eduphoria" AND "Los Angeles Unified School District" AND assessment',
#  '"Otus" AND "Los Angeles Unified School District" AND assessment',
#  '"eDoctrina" AND "Los Angeles Unified School District" AND assessment',
#  '"Mastery Connect" AND "Los Angeles Unified School District" AND assessment',
#  '"performance matters" AND "Los Angeles Unified School District" AND assessment',
#  '"illuminate education" AND "Los Angeles Unified School District" AND assessment',
#  '"FOCALPOINTK12" AND "Los Angeles Unified School District" AND assessment',
#  '"engrade" AND "Los Angeles Unified School District" AND assessment',
#  '"SchoolCity" AND "Los Angeles Unified School District" AND assessment',
#  '"Naiku" AND "Los Angeles Unified School District" AND assessment',
#  '"OARS" AND "Los Angeles Unified School District" AND assessment',
#  '"oncourse " AND "Los Angeles Unified School District" AND assessment',
#  '"schoolnet" AND "Los Angeles Unified School District" AND assessment',
#  '"Assessment Technology Incorporated" AND "Los Angeles Unified School District" AND assessment',
#  '"Edupoint" AND "Los Angeles Unified School District" AND assessment',
#  '"io education" AND "Los Angeles Unified School District" AND assessment',
#  '"Five-star technology solutions" AND "Puerto Rico Department of Education" AND assessment',
#  '"onHands Schools" AND "Puerto Rico Department of Education" AND assessment',
#  '"Edluastic" AND "Puerto Rico Department of Education" AND assessment',
#  '"PowerSchool" AND "Puerto Rico Department of Education" AND assessment',
#  '"eduphoria" AND "Puerto Rico Department of Education" AND assessment',
#  '"Otus" AND "Puerto Rico Department of Education" AND assessment',
#  '"eDoctrina" AND "Puerto Rico Department of Education" AND assessment',
#  '"Mastery Connect" AND "Puerto Rico Department of Education" AND assessment',
#  '"performance matters" AND "Puerto Rico Department of Education" AND assessment',
#  '"illuminate education" AND "Puerto Rico Department of Education" AND assessment',
#  '"FOCALPOINTK12" AND "Puerto Rico Department of Education" AND assessment',
#  '"engrade" AND "Puerto Rico Department of Education" AND assessment',
#  '"SchoolCity" AND "Puerto Rico Department of Education" AND assessment',
#  '"Naiku" AND "Puerto Rico Department of Education" AND assessment',
#  '"OARS" AND "Puerto Rico Department of Education" AND assessment',
#  '"oncourse " AND "Puerto Rico Department of Education" AND assessment',
#  '"schoolnet" AND "Puerto Rico Department of Education" AND assessment',
#  '"Assessment Technology Incorporated" AND "Puerto Rico Department of Education" AND assessment',
#  '"Edupoint" AND "Puerto Rico Department of Education" AND assessment',
#  '"io education" AND "Puerto Rico Department of Education" AND assessment',
#  '"Five-star technology solutions" AND "Chicago Public Schools" AND assessment',
#  '"onHands Schools" AND "Chicago Public Schools" AND assessment',
#  '"Edluastic" AND "Chicago Public Schools" AND assessment',
#  '"PowerSchool" AND "Chicago Public Schools" AND assessment',
#  '"eduphoria" AND "Chicago Public Schools" AND assessment',
#  '"Otus" AND "Chicago Public Schools" AND assessment',
#  '"eDoctrina" AND "Chicago Public Schools" AND assessment',
#  '"Mastery Connect" AND "Chicago Public Schools" AND assessment',
#  '"performance matters" AND "Chicago Public Schools" AND assessment',
#  '"illuminate education" AND "Chicago Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Chicago Public Schools" AND assessment',
#  '"engrade" AND "Chicago Public Schools" AND assessment',
#  '"SchoolCity" AND "Chicago Public Schools" AND assessment',
#  '"Naiku" AND "Chicago Public Schools" AND assessment',
#  '"OARS" AND "Chicago Public Schools" AND assessment',
#  '"oncourse " AND "Chicago Public Schools" AND assessment',
#  '"schoolnet" AND "Chicago Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Chicago Public Schools" AND assessment',
#  '"Edupoint" AND "Chicago Public Schools" AND assessment',
#  '"io education" AND "Chicago Public Schools" AND assessment',
#  '"Five-star technology solutions" AND "Miami-Dade County Public Schools" AND assessment',
#  '"onHands Schools" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Edluastic" AND "Miami-Dade County Public Schools" AND assessment',
#  '"PowerSchool" AND "Miami-Dade County Public Schools" AND assessment',
#  '"eduphoria" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Otus" AND "Miami-Dade County Public Schools" AND assessment',
#  '"eDoctrina" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Mastery Connect" AND "Miami-Dade County Public Schools" AND assessment',
#  '"performance matters" AND "Miami-Dade County Public Schools" AND assessment',
#  '"illuminate education" AND "Miami-Dade County Public Schools" AND assessment',
#  '"FOCALPOINTK12" AND "Miami-Dade County Public Schools" AND assessment',
#  '"engrade" AND "Miami-Dade County Public Schools" AND assessment',
#  '"SchoolCity" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Naiku" AND "Miami-Dade County Public Schools" AND assessment',
#  '"OARS" AND "Miami-Dade County Public Schools" AND assessment',
#  '"oncourse " AND "Miami-Dade County Public Schools" AND assessment',
#  '"schoolnet" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Assessment Technology Incorporated" AND "Miami-Dade County Public Schools" AND assessment',
#  '"Edupoint" AND "Miami-Dade County Public Schools" AND assessment',
#  '"io education" AND "Miami-Dade County Public Schools" AND assessment']

# %% [markdown]
# ## Step 4

# %% [markdown]
# Automatically query either Google or Bing (both pose unique problems), and have the first (most relevant) url returned. Below we are using a module called 'google' in Python to request search terms.

# %%
returned_urls = []
phrase = []
for item in search_terms:
    for url in search(item, start = 1, stop = 2, num = 1, pause = 8):
        returned = url
        returned_urls.append(url)
        phrase.append(item)
returned_urls
phrase

# %% [markdown]
# ## Step 5

# %% [markdown]
# Compile all returned urls, and visual inspect urls to determine any that meet the following criteria: (1) The school district's website, (2) an official document from the school district, (3) the platform's website.

# %%
# put the returned urls and the query phrases into a single dataframe. 
returned_list = pd.DataFrame (
{
 'returned_urls': returned_urls,
 'phrase': phrase
    
})

# %%
pd.set_option("display.max_colwidth", 999)
returned_list
# Out:
#                                                                                              phrase  \
# 0       "Five-star technology solutions" AND "New York City Department of Education" AND assessment
# 1                          "PowerSchool" AND "New York City Department of Education" AND assessment
# 2                            "eduphoria" AND "New York City Department of Education" AND assessment
# 3                                 "Otus" AND "New York City Department of Education" AND assessment
# 4                            "eDoctrina" AND "New York City Department of Education" AND assessment
# 5                      "Mastery Connect" AND "New York City Department of Education" AND assessment
# 6                  "performance matters" AND "New York City Department of Education" AND assessment
# 7                 "illuminate education" AND "New York City Department of Education" AND assessment
# 8                        "FOCALPOINTK12" AND "New York City Department of Education" AND assessment
# 9                              "engrade" AND "New York City Department of Education" AND assessment
# 10                          "SchoolCity" AND "New York City Department of Education" AND assessment
# 11                               "Naiku" AND "New York City Department of Education" AND assessment
# 12                                "OARS" AND "New York City Department of Education" AND assessment
# 13                           "schoolnet" AND "New York City Department of Education" AND assessment
# 14  "Assessment Technology Incorporated" AND "New York City Department of Education" AND assessment
# 15                            "Edupoint" AND "New York City Department of Education" AND assessment
# 16                        "io education" AND "New York City Department of Education" AND assessment
# 17        "Five-star technology solutions" AND "Los Angeles Unified School District" AND assessment
# 18                           "PowerSchool" AND "Los Angeles Unified School District" AND assessment
# 19                             "eduphoria" AND "Los Angeles Unified School District" AND assessment
# 20                                  "Otus" AND "Los Angeles Unified School District" AND assessment
# 21                             "eDoctrina" AND "Los Angeles Unified School District" AND assessment
# 22                       "Mastery Connect" AND "Los Angeles Unified School District" AND assessment
# 23                   "performance matters" AND "Los Angeles Unified School District" AND assessment
# 24                  "illuminate education" AND "Los Angeles Unified School District" AND assessment
# 25                         "FOCALPOINTK12" AND "Los Angeles Unified School District" AND assessment
# 26                               "engrade" AND "Los Angeles Unified School District" AND assessment
# 27                            "SchoolCity" AND "Los Angeles Unified School District" AND assessment
# 28                                 "Naiku" AND "Los Angeles Unified School District" AND assessment
# 29                                  "OARS" AND "Los Angeles Unified School District" AND assessment
# 30                             "oncourse " AND "Los Angeles Unified School District" AND assessment
# 31                             "schoolnet" AND "Los Angeles Unified School District" AND assessment
# 32    "Assessment Technology Incorporated" AND "Los Angeles Unified School District" AND assessment
# 33                              "Edupoint" AND "Los Angeles Unified School District" AND assessment
# 34                          "io education" AND "Los Angeles Unified School District" AND assessment
# 35                           "PowerSchool" AND "Puerto Rico Department of Education" AND assessment
#
#                                                                                                                                                                                                                          returned_urls
# 0                                                                                                                                                                                    https://www.pinterest.com/pin/512284526337160384/
# 1                                                                                                                                                                      http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_Q744.pdf
# 2                                                                                                                                                                          https://pt.scribd.com/document/335816426/The-Band-Directors
# 3                                                                                                                                                                    https://www.imsglobal.org/leadership/technical-advisory-board-tab
# 4                                                                                                                                                     http://www.datag.org/Websites/datagorg/images/Summer_Conference_FINAL_3_bios.pdf
# 5                                                                                                                                                                      http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_Q169.pdf
# 6                                                                                                                                                                      https://www.imsglobal.org/leadership/executive-board-assessment
# 7                                                                                                                                                                    https://www.edsurge.com/news/2016-01-13-teachscape-s-tangled-tale
# 8                                                                                                                                                                                         https://www.imsglobal.org/cc/statuschart.cfm
# 9                                                                                                                                   http://schools.nyc.gov/NR/rdonlyres/0A3F0EF9-CDB5-42AE-9D7D-A9B5201A436B/165486/Forthewebsite.docx
# 10                                                                                                                                                              https://2017learningimpactleadershipinst.sched.com/directory/attendees
# 11                                                                                                                                                                                   https://www.pinterest.com/pin/218565388138218485/
# 12                                                                                                                                                                     http://schools.nyc.gov/documents/oaosi/cep/2009-10/cep_K404.pdf
# 13                                                                                                                                                                     http://schools.nyc.gov/documents/oaosi/cep/2015-16/cep_Q141.pdf
# 14                                                                                                                                                                                              https://www.facebook.com/jody.jepson.9
# 15                                                                                                                                                                 http://pages.nxtbook.com/nxtbooks/pmg/da0711/offline/pmg_da0711.pdf
# 16                                                                                                                                                                     http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_X131.pdf
# 17                                                                                                                      https://cms.bsu.edu/-/media/www/departmentalcontent/teachers/pdfs/new%20cv/salloum%20cv%209%209%2016.pdf?la=en
# 18                                                                                                                                                                                              https://achieve.lausd.net/misischarter
# 19                                                                                                                                                     https://bquintanillaportfolio.files.wordpress.com/2013/01/tcea_2014_program.pdf
# 20                                                                                                                                                        https://www.redfin.com/CA/Los-Angeles/1216-N-Sycamore-Ave-90038/home/7107565
# 21                                                                                                                                 http://educationvotes.nea.org/wp-content/uploads/2017/05/Charter-School-Fraud_Report_2017_rev1a.pdf
# 22                                                                                                                                                                                         https://www.linkedin.com/in/devera-educator
# 23                                                                                                                        http://www.performancematters.com/webinar-the-importance-of-fair-reliable-valid-and-defensible-observations/
# 24                                                                                                                                                                              https://www.illuminateed.com/blog/category/case-study/
# 25                                                                                                                                                                                            https://www.edsurge.com/sitemap_wiki.xml
# 26                                                                                                                                                       https://sunnybraeavenueelementary.files.wordpress.com/2015/07/assessments.pdf
# 27                                                                                                                                                                    http://www.cde.ca.gov/ta/tg/ca/documents/caaspp16evalrptvol1.pdf
# 28                                                                                                                              http://scholarworks.csun.edu/bitstream/handle/10211.3/132919/Tippens-Martin-thesis-2015.pdf;sequence=1
# 29                                                                                                                                         http://www.laschools.org/contractor/lc/documents/download/certification/manual/section5.pdf
# 30  https://achieve.lausd.net/cms/lib/CA01000043/Centricity/domain/168/e-library/reference%20guides%20-%20organized%20by%20date%20newest%20to%20oldest/REF%205994.2%20SCHEDULING%20ELD%20FOR%20SECONDARY%20EL%20SWDS%20COMB.%20PDF.pdf
# 31                                                                                                   https://achieve.lausd.net/site/handlers/filedownload.ashx?moduleinstanceid=16029&dataid=15267&FileName=CCTPUpdates%2011-19-13.pdf
# 32                                                                                                                  https://peopleforstudentrights.com/index.php/complaint/count-18-cusd-pilot-for-national-common-core-implementation
# 33                                                                                                                                                                                           https://www.eiseverywhere.com/ehome/76744
# 34                                                                                                                                                                                         https://www.youtube.com/watch?v=ssW4cpTwKn0
# 35                                                                                                                                                                                     http://www.learningtech.org/company/staff.shtml

# %% [markdown]
# ## Step 6

# %% [markdown]
# Document when a school district or a vendor website explicity states that the platform is used for a given school district.

# %% [markdown]
# ### Examples

# %% [markdown]
# #### "eDoctrina" AND "New York City Department of Education" AND assessment	(KeyData System)
# https://www.regents.nysed.gov/common/regents/files/215p12a3.pdf

# %% [markdown]
# "The school uses ongoing formative and summative assessments and evaluation data to inform instructional decisions and promote student learning. Data analysis is facilitated by the use of a tool called <font color='red'>eDoctrina </font>, which provides assessments, a wide verity of report formats and curriculum tracking."

# %% [markdown]
# #### "Mastery Connect" AND "New York City Department of Education" AND assessment  <p>

# %% [markdown]
# http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_M189.pdf
#
# "We have partnered with Assessment Matters and <font color='red'>Mastery Connect</font> to implement an assessment tool and structure that will support the school in further developing assessment-informed school culture..."

# %% [markdown]
# #### "io education" AND "New York City Department of Education" AND assessment

# %% [markdown]
# http://schools.nyc.gov/documents/oaosi/cep/2016-17/cep_X131.pdf
#
# "Teachers will utilize Skedula and <font color='red'>IO Education</font> to track students grades and assessment data. Students and parents will access Pupil Path to monitor student progress."

# %% [markdown]
# ### <font color='red'> Issues to address </font>

# %% [markdown]
# 1. Google hates when you try and automatically search things, and it will stop working if it feels that a bot is doing the Googling (we could try and get around this by varying and lengthing the times between each request -- not an entirely professional approach). In the example above, it returned 36 of 1000 requests before erroring out.
# 2. Alternatively, we can be copcetic and use Bing. For more than 1000 requests in a month, we have to pay something like $30 dollars. I have done a little proof of concept to see how well it would perform, and the returned URLs are often not the same as with Google (in some cases, not as good; in other cases, just different), but we could probably work to try and improve upon what is being returend by fine-tuning the search terms to better fit how Bing searches (e.g., make sure we are using the correct logic operators, etc).
# 3. This still leaves the manual task of reviewing the urls to see which links are worthy documentation that a school district is using a particular platform (backed by a particular item bank). But, I think that the visual inspection does go pretty quickly -- clearly Pinterest, for example, won't be a link we are interested in pursuing. We could, however, find additional automatic ways to parse the data, so that we are only left with serious candidates to exam.

# %% [markdown]
# ## Thoughts??
